# %%
import os
from dotenv import load_dotenv
load_dotenv()

##os.environ['OPEN_API_KEY']=os.getenv("OPENAI_API_KEY")
os.environ['LANGCHAIN_API_KEY']=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]="my_project"

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    groq_api_key=os.getenv("GROQ_API_KEY"),
    model_name="llama-3.1-8b-instant"
)

# %%
response = llm.invoke("information on Dr. P.C Srikanth")
print(response.content)
# Out:
# I couldn't find any information on Dr. P.C Srikanth. It's possible that he may be a private individual or a professional who hasn't gained significant public attention.
#
# However, I can try to provide some general information on how to find information about a specific person, especially in academic or professional settings:
#
# 1. **Check online directories**: Look for online directories like Academia.edu, ResearchGate, or LinkedIn. These platforms often list professionals and academics.
# 2. **Search Google Scholar**: Google Scholar can help you find publications and research articles authored by Dr. P.C Srikanth.
# 3. **University websites**: If Dr. P.C Srikanth is affiliated with a university, check their website for faculty profiles or departmental listings.
# 4. **Professional networks**: Reach out to colleagues or peers in Dr. P.C Srikanth's field or department to see if they have any information about him.
# 5. **Publications and conferences**: Look for publications or conference presentations by Dr. P.C Srikanth to learn more about his research interests and expertise.
#
# If you have any additional information about Dr. P.C Srikanth, such as his institution, department, or areas of expertise, I may be able to help you find more information about him.
