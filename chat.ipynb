# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['LANGCHAIN_API_KEY']=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]="my_project"

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    groq_api_key=os.getenv("GROQ_API_KEY"),
    model_name="llama-3.1-8b-instant"
)

# %%
response = llm.invoke("list the disteicts in karnataka")
print(response.content)
# Out:
# Karnataka is a state in India that is divided into 31 districts. Here's a list of the districts in Karnataka:
#
# 1. Bagalkot
# 2. Ballari (Bellary)
# 3. Belagavi (Belgaum)
# 4. Bengalore (Urban) - BBMP
# 5. Bengaluru Rural
# 6. Bidar
# 7. Chamarajanagar
# 8. Chikkaballapur
# 9. Chikkamagaluru
# 10. Chitradurga
# 11. Dakshina Kannada (South Canara)
# 12. Davanagere
# 13. Dharwad
# 14. Gadag
# 15. Hassan
# 16. Haveri
# 17. Kodagu
# 18. Kolar
# 19. Koppal
# 20. Mandya
# 21. Mysuru (Mysore)
# 22. Raichur
# 23. Ramanagara
# 24. Shivamogga (Shimoga)
# 25. Tumakuru (Tumkur)
# 26. Udupi
# 27. Uttara Kannada
# 28. Vijayapura (Bijapur)
# 29. Yadgir
# 30. Chitradurga and Tumkur were merged in 2020 and 2022 to respectively form a part of the Chitradurga and Tumkur districts
# 31. 2020 also saw the formation of Shivamogga which was formed from the merging of Shivamogga and  Shivamogga North (Tirthahalli taluk )
